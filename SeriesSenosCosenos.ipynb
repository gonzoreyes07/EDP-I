# %% [markdown]
# <a href="https://colab.research.google.com/github/gonzoreyes07/EDP-I/blob/main/SeriesSenosCosenos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sympy import fourier_series, pi, plot, Piecewise, exp
from sympy.abc import x
import matplotlib.pyplot as plt

# %%
# Fucnion ejercicio 1 y 2 (impar)
f1=Piecewise(
    (exp(2*x),(x >= 0) & (x < 1)),
    (-exp(-2*x),(x >-1) & (x<0))  )

# Fucnion ejercicio 1 y 2 (par)
f2=Piecewise(
    (exp(2*x),(x >= 0) & (x <= 1)),
    (exp(-2*x),(x >-1) & (x<1))  )


# Funciòn a trozos ejercicio 3
f3=Piecewise(
    (1, (x >= 0) & (x <= pi/2)),
    (2, (x > pi/2) & (x<=pi)) )

# %%
plot(f3, (x,-2,2),line_color ='red') # Grafica del ejercicio 3
plot(f1, (x,-2,2),line_color ='green') # Grafica del ejercicio 1 y 2 (impar)
plot(f2, (x,-2,2),line_color ='yellow') # Grafica del ejercicio 1 y 2 (par)

# %%
s = fourier_series(f3, (x, 0, pi)) # Serie de Fourier en el intervalo [0,pi] y truncamos la serie para diferentes tèrminos de nùmeros
s1 = s.truncate(n = 3)
s2 = s.truncate(n = 5)
s3 = s.truncate(n = 7)
p3 = plot(f, s1, s2, s3, (x, 0, pi), show=False, legend=True)

t = fourier_series(f1, (x, 0, 1)) # Serie de Fourier en el intervalo [0,1] y truncamos la serie para diferentes tèrminos de nùmeros
t1 = t.truncate(n = 3)
t2 = t.truncate(n = 5)
t3 = t.truncate(n = 7)
p1 = plot(f1, t1, t2, t3, (x, 0, 1), show=False, legend=True)

u = fourier_series(f2, (x, 0, 1)) # Serie de Fourier en el intervalo [0,1] y truncamos la serie para diferentes tèrminos de nùmeros
u1 = u.truncate(n = 3)
u2 = u.truncate(n = 5)
u3 = u.truncate(n = 7)
p2 = plot(f2, u1, u2, u3, (x, 0, 1), show=False, legend=True)

# %%
s
# Out:
# FourierSeries(Piecewise((1, (x >= 0) & (x <= pi/2)), (2, (x <= pi) & (x > pi/2))), (x, 0, pi), (3/2, SeqFormula(2*Piecewise((-sin(_n*pi)/(2*_n) + sin(2*_n*pi)/_n, (_n > -oo) & (_n < oo) & Ne(_n, 0)), (3*pi/2, True))*cos(2*_n*x)/pi, (_n, 1, oo)), SeqFormula(2*Piecewise((cos(_n*pi)/(2*_n) - cos(2*_n*pi)/_n + 1/(2*_n), (_n > -oo) & (_n < oo) & Ne(_n, 0)), (0, True))*sin(2*_n*x)/pi, (_n, 1, oo))))

# %%
t
# Out:
# FourierSeries(Piecewise((exp(2*x), (x >= 0) & (x < 1)), (-exp(-2*x), (x > -1) & (x < 0))), (x, 0, 1), (-1/2 + exp(2)/2, SeqFormula(2*(_n*pi*exp(2)*sin(2*_n*pi)/(2*_n**2*pi**2 + 2) + exp(2)*cos(2*_n*pi)/(2*_n**2*pi**2 + 2) - 1/(2*_n**2*pi**2 + 2))*cos(2*_n*pi*x), (_n, 1, oo)), SeqFormula(2*(-_n*pi*exp(2)*cos(2*_n*pi)/(2*_n**2*pi**2 + 2) + _n*pi/(2*_n**2*pi**2 + 2) + exp(2)*sin(2*_n*pi)/(2*_n**2*pi**2 + 2))*sin(2*_n*pi*x), (_n, 1, oo))))

# %%
u
# Out:
# FourierSeries(Piecewise((exp(2*x), (x >= 0) & (x <= 1)), (exp(-2*x), (x > -1) & (x < 1))), (x, 0, 1), (-1/2 + exp(2)/2, SeqFormula(2*(_n*pi*exp(2)*sin(2*_n*pi)/(2*_n**2*pi**2 + 2) + exp(2)*cos(2*_n*pi)/(2*_n**2*pi**2 + 2) - 1/(2*_n**2*pi**2 + 2))*cos(2*_n*pi*x), (_n, 1, oo)), SeqFormula(2*(-_n*pi*exp(2)*cos(2*_n*pi)/(2*_n**2*pi**2 + 2) + _n*pi/(2*_n**2*pi**2 + 2) + exp(2)*sin(2*_n*pi)/(2*_n**2*pi**2 + 2))*sin(2*_n*pi*x), (_n, 1, oo))))

# %%
p3[0].label = 'x'
p3[1].label = 'n=3'
p3[2].label = 'n=5'
p3[3].label = 'n=7'

p1[0].label = 'x'
p1[1].label = 'n=3'
p1[2].label = 'n=5'
p1[3].label = 'n=7'

p2[0].label = 'x'
p2[1].label = 'n=3'
p2[2].label = 'n=5'
p2[3].label = 'n=7'

# %%
p3.show()

# %%
p1.show()

# %%
p2.show()
