# %% [markdown]
# <a href="https://colab.research.google.com/github/gonzoreyes07/EDP-I/blob/main/Ondas_viajeras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def onda(x):
    return np.exp(-(x - 0.5)**2 / 0.01) # Graficamos la función dada

val_x = np.linspace(0, 1, 100)
plt.plot(val_x, onda(val_x))
plt.xlabel("")
plt.ylabel("")
plt.title("Perturbacion en una cuerda de f'(x)")
plt.show()

# %%
# Realizamos el primer cambio de variable y consideramos los siguientes tiempos y velocidad de onda
c=0.1
t_values=[0,0.5,1]

# %%
# Realizamos la gráfica con su desplazamiento a la derecha
for t in t_values:
    x_values = np.linspace(0, 2, 200)
    x_der = x_values - c * t
    plt.plot(x_values, onda(x_der), label=f't = {t}')

plt.xlabel("x")
plt.ylabel("f'(x-ct)")
plt.title("Desplazamiento de la perturbacion a la derecha")
plt.legend()
plt.show()

# %%
# Realizamos el segundo cambio de variable y agregamos tiempo y velocidad de onda
c=0.1
t_values=[0,0.5,1]

# %%
# Graficamos la perturbación de la cuerda con su desplazamiento a la izquierda
for t in t_values:
    x_values = np.linspace(0, 2, 200)
    x_izq = x_values + c * t
    plt.plot(x_values, onda(x_izq), label=f't = {t}')

plt.xlabel("x")
plt.ylabel("f'(x-ct)")
plt.title("Desplazamiento de la perturbacion a la izquierda")
plt.legend()
plt.show()

# %%
# Ahora elegimos un tiempo y una velocidad de onda
c=0.1
t_values=[0, 0.5, 1]

# %%
# Realizamos la superposición de las ondas viajeras usando los primeros dos incisos
x_values = np.linspace(0, 2, 200)

def onda(x):
    return np.exp(-(x - 0.5)**2 / 0.01)

for t in t_values:
    x_der = x_values - c * t
    x_izq = x_values + c * t
    y = 0.5 * (onda(x_der) + onda(x_izq))
    plt.plot(x_values, y, label=f't = {t} (superposición)', linestyle=':', linewidth=3)

plt.xlabel("x")
plt.ylabel("Superposición")
plt.title("Superposición de ondas viajeras")
plt.legend()
plt.show()
